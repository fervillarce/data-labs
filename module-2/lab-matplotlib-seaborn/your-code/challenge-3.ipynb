# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
titanic.get_dtype_counts()
# Out:
# float64    3
# int64      4
# object     5
# dtype: int64

# %%
# your code here- numerical variable
titanic.select_dtypes([int,float]).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable
titanic.select_dtypes(object).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib as mpl
mpl.style.use('classic')
plt.subplots(figsize=(12,6))
# Out:
# (<Figure size 960x480 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1160ffac8>)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %% [markdown]
# Media de unos 29 años, primer cuartil de unos 22 años, y tercer cuartil de unos 37. <br>
# Se ve que los outliers aparecen a partir de los 59 años.

# %%
# your code here
# Los gráficos que mejor permiten ver la distribución de edades son el histograma y el de violín.
plt.hist(titanic['Age'])
plt.show()

# %%
sns.set()
sns.violinplot(titanic['Age'])
plt.show()

# %%
# Los juntos en subplots, junto con el boxplot.
f, ax = plt.subplots(1, 3, figsize=(20,10))
ax[0].hist(titanic['Age'])
ax[1].violinplot(titanic['Age'])
ax[2].boxplot(titanic['Age'])
plt.tight_layout();

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
f, ax = plt.subplots(1,3, figsize=(20,10))
ax[0].hist(titanic['Age'], bins = 10)
ax[1].hist(titanic['Age'], bins = 20)
ax[2].hist(titanic['Age'], bins = 50)
plt.tight_layout();

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
# Sí, afecta, porque divide el histograma en más contenedores, ofreciendo más detalle en cada una de las franjas.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age']);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot.bar()
plt.show()

# %%
# your code here- 2nd way
sns.countplot(titanic['Gender'])
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
# Puedo usar cualquiera de los dos anteriores (matplotlib o seaborn). Uso seaborn.
sns.countplot(titanic['Pclass'])
plt.show()

# %%
# Que es como si hiciéramos:
titanic.groupby(titanic['Pclass'])['Age'].count()
# Out:
# Pclass
# 1    323
# 2    277
# 3    709
# Name: Age, dtype: int64

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'])
plt.show()

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# Mediana de unos 29 años, media de unos 30, primer cuartil de unos 22 años, y tercer cuartil de unos 37.
# Mínimna edad de cero años y máxima de 80.
# Se ve que los outliers aparecen a partir de los 59 años.

# Compruebo:
titanic['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
plt.hist(titanic['Age'], bins = 20)
plt.show()

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# Nos proporciona concretamente el número de personas por rango de edad.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way - Con Seaborn
sns.set()
sns.scatterplot(titanic['Age'], titanic['Fare']);

# %%
# your code-2nd way - Con Matplotlib
plt.scatter(titanic['Age'], titanic['Fare'])
plt.xlabel('Age', fontsize = 15) # En seaborn el label se pone automáticamente pero con matplotlib no.
plt.ylabel('Fare', fontsize = 15);

# %% [markdown]
# No se ve una relación lineal clara entre Age y Fare. Lo que sí se puede concluir es que, independientemente de la edad, el precio de la gran mayoría de los billetes es menor de $50, que corresponderán a los de clase 3. Ya vimos en clase 3 había unos 700 pasajeros, más que los de clase 1 y clase 2 juntos.

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic.corr(), annot = True)
plt.show()

# %%
#your code here
# Ahora uso la scatter_matrix de pandas.
pd.plotting.scatter_matrix(titanic, figsize=(16,16))
plt.show()

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# De acuerdo al heatmap, la pareja de variables más correlacionada es Parch-SibSp
# sibsp -> Number of Siblings/Spouses Aboard
# parch -> Number of Parents/Children Aboard
# Personalmente, no veo una correlación entre estas dos variables. Una es el número de hermanxs+esposx y el otro el número de padres+hijos a bordo. Lo que creo

# %% [markdown]
# De acuerdo al heatmap, la pareja de variables más correlacionada es Parch-SibSp, donde: <br>
# sibsp -> Number of Siblings/Spouses Aboard <br>
# parch -> Number of Parents/Children Aboard <br>
# <br>
# Personalmente, no veo una correlación entre estas dos variables. Una es el número de hermanxs+esposx y el otro el número de padres+hijos a bordo. Lo que creo es que estas dos variables siempre van a ser números enteros no mayores que 6, siendo la mayoría de las veces valores pequeños y siendo más probable que tanto sibsp como parch tiendan a cero. <br>
# <br>
# Esa es la relación que vea, que ambos valores tienden a cero.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
# Hago un loop para imprimir los boxplot de edad (numérico) para cada una de las clases (categórico, ya que aunque sean números, para mi es primera, segunda y tercera clase).
# Sé que hay 3 clases, pero lo hago como si lo desconociera.

number_of_classes = len(titanic['Pclass'].unique())

f, ax = plt.subplots(1, number_of_classes, figsize=(20,10))
for i,clase in enumerate(titanic['Pclass'].sort_values().unique()):
    ax[i].boxplot(titanic[titanic['Pclass'] == clase]['Age'])
    ax[i].set_title("Edades en clase " + str(clase), fontsize = 25)

plt.tight_layout();

# %%
# Se puede apreciar claramente, que a mayor clase, mayor media de edad y mayor máxima de edad.

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic)
g.map(plt.hist, "tip")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-2600222c8929> in <module>
#       1 #your code here
#       2 g = sns.FacetGrid(titanic)
# ----> 3 g.map(plt.hist, "tip")
#
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     742
#     743             # Get the actual data we are going to plot with
# --> 744             plot_data = data_ijk[list(args)]
#     745             if self._dropna:
#     746                 plot_data = plot_data.dropna()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ...
