# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1) # Una fila (nrows) por 2 columnas (ncols) de gráficas. Esta va en la primera posición (index)
plt.plot(x, y, color = 'green' , linewidth = 2) # se puede poner lw en lugar de linewidth y ls en lugar de linestyle

plt.subplot(1,2,2)
plt.plot(x, z, color = 'b' , linewidth = 2, linestyle = "--")

plt.tight_layout() # Esta función deja el padding más limpio. Se pone al final.

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,axes = plt.subplots(1,2)
axes[0].plot(x, y, color="g", lw=2, ls='-')
axes[1].plot(x, z, color="b", lw=2, ls='--')

plt.tight_layout()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
plt.subplots(figsize=(10,4)) # También se puede hacer plt.figure(figsize=(10,10))

plt.subplot(1,2,1)
plt.plot(x, y, color = 'green' , linewidth = 2)
plt.grid(True) # Para mostrar las gridlines

plt.subplot(1,2,2)
plt.plot(x, z, color = 'b' , linewidth = 2, linestyle = "--")

plt.grid(True)
plt.tight_layout()

# %%
# your code here
# Haciéndolo de la otra forma.
fig,axes = plt.subplots(1,2, figsize=(10,4))

axes[0].plot(x, y, color="g", lw=2)
axes[1].plot(x, z, color="b", lw=2, ls='--')

axes[0].grid(True)
axes[1].grid(True)
plt.tight_layout()

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
plt.subplots(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(x, y, color = 'green' , linewidth = 2)
plt.grid(True) # Para mostrar las gridlines
plt.ylabel('Ordenadas', fontsize = 15)
plt.xlabel('Abcisas', fontsize = 15)
plt.title("Lineal") # Añado título

plt.subplot(1,2,2)
plt.plot(x, z, color = 'b' , linewidth = 2, linestyle = "--")
plt.grid(True)
plt.ylabel('Ordenadas', fontsize = 15)
plt.xlabel('Abcisas', fontsize = 15)
plt.title("Cuadrática")

plt.tight_layout()

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
c = x**2
e = np.exp(x)

fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, c, x, e)
axes[0].set_title("Normal scale")

axes[1].plot(x, c, x, e)
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale") # Lo mismo que plt.title("Logarithmic scale")
# Out:
# Text(0.5, 1.0, 'Logarithmic scale')
